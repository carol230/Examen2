# %%
# %load_ext autoreload

# %% [markdown]
# # ODE

# %% [markdown]
# ## Ejercicio 1
# $y'= -5y+5t^2+2t$
# * $0 \le t \le 1$
# * $y(t_0)=1/3$
# * $N=10$

# %%
# %autoreload 2
from src import ODE_euler
# Out:
# [02-06 12:31:08][INFO] 2025-02-06 12:31:08.750464
# [02-06 12:31:09][INFO] david| 2025-02-06 12:31:09.762462
# [02-06 12:31:09][INFO] 2025-02-06 12:31:09.764463
# [02-06 12:31:09][INFO] david| 2025-02-06 12:31:09.766883

# %% [markdown]
# ## Comparación con la solución real
# La solución real de la ecuación diferencial es:
# $y(t)=t^2 +1/3e^{-5t}$
#
# * Grafique la solución real y la aproximación obtenida con el método de Euler en una misma gráfica.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t, y):
    return -5*y + 5*t**2 + 2*t

def f_real(t):
    return t**2 + 1/3 * np.exp(-5 * t)

a, b = 0, 1
y_t0=1/3
N=10
y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)



t_real = np.linspace(a, b, 400)
y_real = f_real(t_real)

plt.plot(t_values, y_values, label='Euler con N=10', marker='o', color = 'yellow')
plt.plot(t_real, y_real, label=' Solucion Exacta', linestyle='--', color = 'red')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Euler con N=10')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Errores
# Calcule el error relativo para diferentes valores de N.

# %%
a, b = 0, 1
y_t0=1/3
N=10
y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

y_exact = np.interp(t_values, t_real, y_real)

error = np.abs((y_values - y_exact) / y_exact)

promedio_error = np.mean(error)

print(f'Error promedio: {promedio_error}')
# Out:
# Error promedio: 0.12910030634016156

# %%
a, b = 0, 1
y_t0=1/3
N=20
y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)
y_exact = np.interp(t_values, t_real, y_real)

error = np.abs((y_values - y_exact) / y_exact)

promedio_error = np.mean(error)

print(f'Error promedio: {promedio_error}')
# Out:
# Error promedio: 0.06315171657579989

# %%
a, b = 0, 1
y_t0=1/3
N=5
y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

error = np.abs((y_values - y_exact) / y_exact)

promedio_error = np.mean(error)

print(f'Error promedio: {promedio_error}')
# Out:
# Error promedio: 0.279792972767494
